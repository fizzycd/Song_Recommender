# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
import random
from IPython.display import IFrame

# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# ## importing song database

# %%
fetch = pd.read_csv("library_3366rows.csv")

# %%
fetch.describe()
# Out:
#         popularity  danceability       energy          key     loudness  \
# count  3366.000000   3366.000000  3366.000000  3366.000000  3366.000000
# mean     62.619133      0.622207     0.561327     5.297980    -9.877750
# std      18.598884      0.162957     0.284895     3.617775     7.222636
# min       0.000000      0.107000     0.002900     0.000000   -40.436000
# 25%      55.000000      0.508000     0.334250     2.000000   -12.151000
# 50%      68.000000      0.634000     0.630000     5.000000    -7.108000
# 75%      75.000000      0.747000     0.798000     8.000000    -5.006000
# max     100.000000      0.975000     0.996000    11.000000    -0.517000
#
#               mode  acousticness  instrumentalness     liveness      valence  \
# count  3366.000000   3366.000000       3366.000000  3366.000000  3366.000000
# mean      0.613191      0.340301          0.247896     0.172365     0.445314
# std       0.487092      0.365899          0.391199     0.139933     0.253968
# min       0.000000      0.000005          0.000000     0.024400     0.033800
# 25%       0.000000      0.027500          0.000000     0.093900     0.225000
# 50%       1.000000      0.165000          0.000032     0.115000     0.430000
# 75%       1.000000      0.694000          0.740500     0.202000     0.648000
# max       1.000000      0.996000          0.977000     0.960000     0.978000
#
#              tempo    duration_ms  time_signature
# count  3366.000000    3366.000000     3366.000000
# mean    118.979237  205539.008318        3.907011
# std      28.990452   64131.790248        0.397576
# min      40.001000   41757.000000        1.000000
# 25%      96.038000  160000.000000        4.000000
# 50%     119.994500  198980.500000        4.000000
# 75%     138.181500  237275.000000        4.000000
# max     210.164000  578041.000000        5.000000

# %%
fetch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3366 entries, 0 to 3365
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3366 non-null   object
#  1   title             3366 non-null   object
#  2   all_artists       3366 non-null   object
#  3   popularity        3366 non-null   int64
#  4   release_date      3366 non-null   object
#  5   danceability      3366 non-null   float64
#  6   energy            3366 non-null   float64
#  7   key               3366 non-null   int64
#  8   loudness          3366 non-null   float64
#  9   mode              3366 non-null   int64
#  10  acousticness      3366 non-null   float64
#  11  instrumentalness  3366 non-null   float64
#  12  liveness          3366 non-null   float64
#  13  valence           3366 non-null   float64
#  14  tempo             3366 non-null   float64
#  15  duration_ms       3366 non-null   int64
#  16  time_signature    3366 non-null   int64
# dtypes: float64(8), int64(5), object(4)
# memory usage: 447.2+ KB

# %% [markdown]
# ## cleaning DF

# %%
duplicateRows = fetch[fetch.duplicated()]
duplicateRows
# Out:
#                           id                                    title  \
# 475   5sNESr6pQfIhL3krM8CtZn                            Numb / Encore
# 552   1bDbXMyjaUIooNwFE9wn0N                                Rich Flex
# 572   0yLdNVWF3Srea0uzk55zFn                                  Flowers
# 573   1Qrg8KqiBpW07V7PNxwwwL                                Kill Bill
# 574   4nrPB8O7Y7wsOCJdgXkthe    Shakira: Bzrp Music Sessions, Vol. 53
# ...                      ...                                      ...
# 2202  3vZO25GdYuqFrR1kzZADnp                             Ready or Not
# 2207  5Tbpp3OLLClPJF8t1DmrFD                  Nuthin' But A "G" Thang
# 3086  2K9kZpwD2CzTa6iiSYYOoO                                     Leão
# 3150  0mBP9X2gPCuapvpZ7TGDk3  Left and Right (Feat. Jung Kook of BTS)
# 3359  1DlczmjByrS4qxRVfGjpqN             My Universe - Galantis Remix
#
#            all_artists  popularity release_date  danceability  energy  key  \
# 475        Linkin Park          75   2004-11-30         0.687   0.793    2
# 552          21 Savage          90   2022-11-04         0.561   0.520   11
# 572        Miley Cyrus         100   2023-01-13         0.707   0.681    0
# 573                SZA          91   2022-12-08         0.644   0.735    8
# 574            Shakira          96   2023-01-11         0.778   0.632    2
# ...                ...         ...          ...           ...     ...  ...
# 2202              Pras          69   1996-02-13         0.607   0.422   10
# 2207        Snoop Dogg          69   1992-12-15         0.669   0.821   11
# 3086  Marília Mendonça          87   2022-12-09         0.743   0.865    6
# 3150               BTS          80   2022-06-24         0.881   0.592    2
# 3359          Galantis          59   2021-10-11         0.596   0.915    4
#
#       loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 475     -4.254     1       0.06030          0.000000    0.5820    0.751
# 552     -9.342     0       0.05030          0.000002    0.3550    0.424
# 572     -4.325     1       0.06320          0.000005    0.0322    0.646
# 573     -5.747     1       0.05210          0.144000    0.1610    0.418
# 574     -5.600     0       0.27400          0.000000    0.0915    0.498
# ...        ...   ...           ...               ...       ...      ...
# 2202   -13.364     0       0.20900          0.000000    0.0839    0.563
# 2207    -4.370     0       0.00182          0.000000    0.1470    0.684
# 3086    -3.897     1       0.44900          0.000003    0.2970    0.794
# 3150    -4.898     1       0.61900          0.000013    0.0901    0.719
# 3359    -4.711     1       0.09490          0.000002    0.1200    0.629
#
#         tempo  duration_ms  time_signature
# 475   107.045       205733               4
# 552   153.150       239360               3
# 572   117.999       200455               4
# 573    88.980       153947               4
# 574   122.104       218289               4
# ...       ...          ...             ...
# 2202  130.470       226987               3
# 2207   94.895       237573               4
# 3086  129.999       166775               4
# 3150  101.058       154487               4
# 3359  120.024       224908               4
#
# [352 rows x 17 columns]

# %%
fetch.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
num_col = fetch.select_dtypes(include=np.number)
num_col = num_col.columns
fetch[num_col]
# Out:
#       popularity  danceability  energy  key  loudness  mode  acousticness  \
# 0             62         0.711   0.838    2    -7.985     1       0.29200
# 1             49         0.746   0.749   11   -10.482     0       0.00567
# 2             17         0.544   0.872    5    -7.444     0       0.00794
# 3             27         0.753   0.915    4    -8.609     0       0.00104
# 4             31         0.685   0.810    2    -8.179     1       0.00020
# ...          ...           ...     ...  ...       ...   ...           ...
# 3361          51         0.436   0.948    1    -5.515     0       0.09740
# 3362          43         0.635   0.167    9   -21.117     0       0.89300
# 3363          43         0.665   0.712    6    -6.841     0       0.00115
# 3364          47         0.535   0.382    1   -18.760     1       0.85200
# 3365          48         0.598   0.356    9   -18.009     1       0.91200
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.927000    0.1460   0.2230  124.002       224274
# 1             0.366000    0.2280   0.0342  123.988       178064
# 2             0.877000    0.1180   0.1820  123.033       265366
# 3             0.883000    0.0608   0.1040  120.008       233662
# 4             0.899000    0.0900   0.0869  123.994       435322
# ...                ...       ...      ...      ...          ...
# 3361          0.003750    0.1400   0.6960  122.609       199136
# 3362          0.000000    0.5010   0.7120  100.544       147694
# 3363          0.000187    0.2700   0.4890  105.017       279318
# 3364          0.000000    0.3110   0.6090   86.969       148073
# 3365          0.000000    0.9130   0.8170  121.045       131907
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3361               4
# 3362               3
# 3363               4
# 3364               4
# 3365               3
#
# [3014 rows x 13 columns]

# %%
# scaling test
num_col = fetch.select_dtypes(include=np.number)
num_col = num_col.columns
scaler = StandardScaler()
fetch[num_col] = scaler.fit_transform(fetch[num_col])
fetch
# Out:
#                           id                              title   all_artists  \
# 0     6ziqWx82jgkQYhyIALoraH   Transmission - Joris Voorn Remix   Joris Voorn
# 1     62piGIpUTsY8HA7tdjfLS8                           Electric      SANDHAUS
# 2     2QlUkqLbDDxDpiMcW7OJrZ  Dreaming - Casper Cole Remix Edit   Casper Cole
# 3     77FpsyFq4vGchrHovA8EyU                              Lissu         Wassu
# 4     3YDBOFmBEk19AS4t4gwpXq                            Arrival      Einmusik
# ...                      ...                                ...           ...
# 3361  5FvxRvrQ8qzKjBJ6ST9aiu   My Universe - David Guetta Remix  David Guetta
# 3362  2giNwwft9s8E5Or8N0olgc                 Skit: Expectation!           BTS
# 3363  6Lgbf4b6c9fwz24eFEWONX      My Universe - Supernova 7 Mix           BTS
# 3364  53XrsilgguJmmsEtDsj0yY               Skit: R U Happy Now?           BTS
# 3365  4Ut6UU8Yyihz1jCZWSCQpu             Skit: Circle Room Talk           BTS
#
#       popularity release_date  danceability    energy       key  loudness  \
# 0       0.070439   2022-10-28      0.555006  1.000686 -0.905065  0.307726
# 1      -0.628992   2022-11-25      0.768562  0.695290  1.588161 -0.026553
# 2      -2.350669   2022-10-07     -0.463960  1.117355 -0.073990  0.380151
# 3      -1.812645   2023-01-13      0.811273  1.264906 -0.351015  0.224190
# 4      -1.597435   2022-11-11      0.396365  0.904607 -0.905065  0.281755
# ...          ...          ...           ...       ...       ...       ...
# 3361   -0.521387   2021-10-13     -1.122932  1.378143 -1.182090  0.638391
# 3362   -0.951806   2015-04-29      0.091285 -1.301798  1.034111 -1.450286
# 3363   -0.951806   2021-09-27      0.274333  0.568327  0.203035  0.460876
# 3364   -0.736597   2013-09-11     -0.518874 -0.564042 -1.182090 -1.134749
# 3365   -0.682794   2013-06-12     -0.134474 -0.653259  1.034111 -1.034211
#
#           mode  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.795993     -0.180622          1.614257 -0.180952 -0.829171  0.183411
# 1    -1.256293     -0.944300          0.225070  0.403730 -1.572915  0.182930
# 2    -1.256293     -0.938245          1.490443 -0.380599 -0.990683  0.150130
# 3    -1.256293     -0.956649          1.505301 -0.788451 -1.297950  0.046234
# 4     0.795993     -0.958889          1.544921 -0.580247 -1.365313  0.183136
# ...        ...           ...               ...       ...       ...       ...
# 3361 -1.256293     -0.699644         -0.671958 -0.223733  1.034126  0.135567
# 3362 -1.256293      1.422320         -0.681244  2.350294  1.097155 -0.622273
# 3363 -1.256293     -0.956355         -0.680781  0.703202  0.218687 -0.468644
# 3364  0.795993      1.312968         -0.681244  0.995543  0.691405 -1.088518
# 3365  0.795993      1.472995         -0.681244  5.287965  1.510783  0.081850
#
#       duration_ms  time_signature
# 0        0.319202        0.236985
# 1       -0.390785        0.236985
# 2        0.950553        0.236985
# 3        0.463442        0.236985
# 4        3.561816        0.236985
# ...           ...             ...
# 3361    -0.067027        0.236985
# 3362    -0.857400       -2.209154
# 3363     1.164917        0.236985
# 3364    -0.851577        0.236985
# 3365    -1.099957       -2.209154
#
# [3014 rows x 17 columns]

# %%
X_scaled_df = pd.DataFrame(data=fetch, columns = fetch.columns)
X_scaled_df
# Out:
#                           id                              title   all_artists  \
# 0     6ziqWx82jgkQYhyIALoraH   Transmission - Joris Voorn Remix   Joris Voorn
# 1     62piGIpUTsY8HA7tdjfLS8                           Electric      SANDHAUS
# 2     2QlUkqLbDDxDpiMcW7OJrZ  Dreaming - Casper Cole Remix Edit   Casper Cole
# 3     77FpsyFq4vGchrHovA8EyU                              Lissu         Wassu
# 4     3YDBOFmBEk19AS4t4gwpXq                            Arrival      Einmusik
# ...                      ...                                ...           ...
# 3361  5FvxRvrQ8qzKjBJ6ST9aiu   My Universe - David Guetta Remix  David Guetta
# 3362  2giNwwft9s8E5Or8N0olgc                 Skit: Expectation!           BTS
# 3363  6Lgbf4b6c9fwz24eFEWONX      My Universe - Supernova 7 Mix           BTS
# 3364  53XrsilgguJmmsEtDsj0yY               Skit: R U Happy Now?           BTS
# 3365  4Ut6UU8Yyihz1jCZWSCQpu             Skit: Circle Room Talk           BTS
#
#       popularity release_date  danceability    energy       key  loudness  \
# 0       0.070439   2022-10-28      0.555006  1.000686 -0.905065  0.307726
# 1      -0.628992   2022-11-25      0.768562  0.695290  1.588161 -0.026553
# 2      -2.350669   2022-10-07     -0.463960  1.117355 -0.073990  0.380151
# 3      -1.812645   2023-01-13      0.811273  1.264906 -0.351015  0.224190
# 4      -1.597435   2022-11-11      0.396365  0.904607 -0.905065  0.281755
# ...          ...          ...           ...       ...       ...       ...
# 3361   -0.521387   2021-10-13     -1.122932  1.378143 -1.182090  0.638391
# 3362   -0.951806   2015-04-29      0.091285 -1.301798  1.034111 -1.450286
# 3363   -0.951806   2021-09-27      0.274333  0.568327  0.203035  0.460876
# 3364   -0.736597   2013-09-11     -0.518874 -0.564042 -1.182090 -1.134749
# 3365   -0.682794   2013-06-12     -0.134474 -0.653259  1.034111 -1.034211
#
#           mode  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.795993     -0.180622          1.614257 -0.180952 -0.829171  0.183411
# 1    -1.256293     -0.944300          0.225070  0.403730 -1.572915  0.182930
# 2    -1.256293     -0.938245          1.490443 -0.380599 -0.990683  0.150130
# 3    -1.256293     -0.956649          1.505301 -0.788451 -1.297950  0.046234
# 4     0.795993     -0.958889          1.544921 -0.580247 -1.365313  0.183136
# ...        ...           ...               ...       ...       ...       ...
# 3361 -1.256293     -0.699644         -0.671958 -0.223733  1.034126  0.135567
# 3362 -1.256293      1.422320         -0.681244  2.350294  1.097155 -0.622273
# 3363 -1.256293     -0.956355         -0.680781  0.703202  0.218687 -0.468644
# 3364  0.795993      1.312968         -0.681244  0.995543  0.691405 -1.088518
# 3365  0.795993      1.472995         -0.681244  5.287965  1.510783  0.081850
#
#       duration_ms  time_signature
# 0        0.319202        0.236985
# 1       -0.390785        0.236985
# 2        0.950553        0.236985
# 3        0.463442        0.236985
# 4        3.561816        0.236985
# ...           ...             ...
# 3361    -0.067027        0.236985
# 3362    -0.857400       -2.209154
# 3363     1.164917        0.236985
# 3364    -0.851577        0.236985
# 3365    -1.099957       -2.209154
#
# [3014 rows x 17 columns]

# %% [markdown]
# ## scaling prep

# %%
df = fetch.select_dtypes(include=np.number)
df
# Out:
#       popularity  danceability    energy       key  loudness      mode  \
# 0       0.070439      0.555006  1.000686 -0.905065  0.307726  0.795993
# 1      -0.628992      0.768562  0.695290  1.588161 -0.026553 -1.256293
# 2      -2.350669     -0.463960  1.117355 -0.073990  0.380151 -1.256293
# 3      -1.812645      0.811273  1.264906 -0.351015  0.224190 -1.256293
# 4      -1.597435      0.396365  0.904607 -0.905065  0.281755  0.795993
# ...          ...           ...       ...       ...       ...       ...
# 3361   -0.521387     -1.122932  1.378143 -1.182090  0.638391 -1.256293
# 3362   -0.951806      0.091285 -1.301798  1.034111 -1.450286 -1.256293
# 3363   -0.951806      0.274333  0.568327  0.203035  0.460876 -1.256293
# 3364   -0.736597     -0.518874 -0.564042 -1.182090 -1.134749  0.795993
# 3365   -0.682794     -0.134474 -0.653259  1.034111 -1.034211  0.795993
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -0.180622          1.614257 -0.180952 -0.829171  0.183411
# 1        -0.944300          0.225070  0.403730 -1.572915  0.182930
# 2        -0.938245          1.490443 -0.380599 -0.990683  0.150130
# 3        -0.956649          1.505301 -0.788451 -1.297950  0.046234
# 4        -0.958889          1.544921 -0.580247 -1.365313  0.183136
# ...            ...               ...       ...       ...       ...
# 3361     -0.699644         -0.671958 -0.223733  1.034126  0.135567
# 3362      1.422320         -0.681244  2.350294  1.097155 -0.622273
# 3363     -0.956355         -0.680781  0.703202  0.218687 -0.468644
# 3364      1.312968         -0.681244  0.995543  0.691405 -1.088518
# 3365      1.472995         -0.681244  5.287965  1.510783  0.081850
#
#       duration_ms  time_signature
# 0        0.319202        0.236985
# 1       -0.390785        0.236985
# 2        0.950553        0.236985
# 3        0.463442        0.236985
# 4        3.561816        0.236985
# ...           ...             ...
# 3361    -0.067027        0.236985
# 3362    -0.857400       -2.209154
# 3363     1.164917        0.236985
# 3364    -0.851577        0.236985
# 3365    -1.099957       -2.209154
#
# [3014 rows x 13 columns]

# %%
df.drop('popularity', axis=1, inplace=True)
df
# Out:
#       danceability    energy       key  loudness      mode  acousticness  \
# 0         0.555006  1.000686 -0.905065  0.307726  0.795993     -0.180622
# 1         0.768562  0.695290  1.588161 -0.026553 -1.256293     -0.944300
# 2        -0.463960  1.117355 -0.073990  0.380151 -1.256293     -0.938245
# 3         0.811273  1.264906 -0.351015  0.224190 -1.256293     -0.956649
# 4         0.396365  0.904607 -0.905065  0.281755  0.795993     -0.958889
# ...            ...       ...       ...       ...       ...           ...
# 3361     -1.122932  1.378143 -1.182090  0.638391 -1.256293     -0.699644
# 3362      0.091285 -1.301798  1.034111 -1.450286 -1.256293      1.422320
# 3363      0.274333  0.568327  0.203035  0.460876 -1.256293     -0.956355
# 3364     -0.518874 -0.564042 -1.182090 -1.134749  0.795993      1.312968
# 3365     -0.134474 -0.653259  1.034111 -1.034211  0.795993      1.472995
#
#       instrumentalness  liveness   valence     tempo  duration_ms  \
# 0             1.614257 -0.180952 -0.829171  0.183411     0.319202
# 1             0.225070  0.403730 -1.572915  0.182930    -0.390785
# 2             1.490443 -0.380599 -0.990683  0.150130     0.950553
# 3             1.505301 -0.788451 -1.297950  0.046234     0.463442
# 4             1.544921 -0.580247 -1.365313  0.183136     3.561816
# ...                ...       ...       ...       ...          ...
# 3361         -0.671958 -0.223733  1.034126  0.135567    -0.067027
# 3362         -0.681244  2.350294  1.097155 -0.622273    -0.857400
# 3363         -0.680781  0.703202  0.218687 -0.468644     1.164917
# 3364         -0.681244  0.995543  0.691405 -1.088518    -0.851577
# 3365         -0.681244  5.287965  1.510783  0.081850    -1.099957
#
#       time_signature
# 0           0.236985
# 1           0.236985
# 2           0.236985
# 3           0.236985
# 4           0.236985
# ...              ...
# 3361        0.236985
# 3362       -2.209154
# 3363        0.236985
# 3364        0.236985
# 3365       -2.209154
#
# [3014 rows x 12 columns]

# %% [markdown]
# ## scaling to cluster

# %%
scaler = StandardScaler()
scaler.fit(df)
X_scaled = scaler.transform(df)
X_scaled_df = pd.DataFrame(X_scaled, columns = df.columns)
display(df.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability    energy       key  loudness      mode  acousticness  \
# 0      0.555006  1.000686 -0.905065  0.307726  0.795993     -0.180622
# 1      0.768562  0.695290  1.588161 -0.026553 -1.256293     -0.944300
# 2     -0.463960  1.117355 -0.073990  0.380151 -1.256293     -0.938245
# 3      0.811273  1.264906 -0.351015  0.224190 -1.256293     -0.956649
# 4      0.396365  0.904607 -0.905065  0.281755  0.795993     -0.958889
#
#    instrumentalness  liveness   valence     tempo  duration_ms  time_signature
# 0          1.614257 -0.180952 -0.829171  0.183411     0.319202        0.236985
# 1          0.225070  0.403730 -1.572915  0.182930    -0.390785        0.236985
# 2          1.490443 -0.380599 -0.990683  0.150130     0.950553        0.236985
# 3          1.505301 -0.788451 -1.297950  0.046234     0.463442        0.236985
# 4          1.544921 -0.580247 -1.365313  0.183136     3.561816        0.236985
#    danceability    energy       key  loudness      mode  acousticness  \
# 0      0.555006  1.000686 -0.905065  0.307726  0.795993     -0.180622
# 1      0.768562  0.695290  1.588161 -0.026553 -1.256293     -0.944300
# 2     -0.463960  1.117355 -0.073990  0.380151 -1.256293     -0.938245
# 3      0.811273  1.264906 -0.351015  0.224190 -1.256293     -0.956649
# 4      0.396365  0.904607 -0.905065  0.281755  0.795993     -0.958889
#
#    instrumentalness  liveness   valence     tempo  duration_ms  time_signature
# 0          1.614257 -0.180952 -0.829171  0.183411     0.319202        0.236985
# 1          0.225070  0.403730 -1.572915  0.182930    -0.390785        0.236985
# 2          1.490443 -0.380599 -0.990683  0.150130     0.950553        0.236985
# 3          1.505301 -0.788451 -1.297950  0.046234     0.463442        0.236985
# 4          1.544921 -0.580247 -1.365313  0.183136     3.561816        0.236985

# %% [markdown]
# ## Clustering with K-Means

# %%
kmeans = KMeans(n_clusters=13, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=13, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([ 8,  7,  0, ...,  7,  6, 12])

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(df.to_numpy()[row_ix, 1], df.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled_df)
clusters
#pd.Series(clusters).value_counts().sort_index()
# Out:
# array([16, 11, 11, ...,  9, 13, 18])

# %%
#X_df = pd.DataFrame(X)
df["cluster"] = clusters
df
# Out:
#                           id                              title   all_artists  \
# 0     6ziqWx82jgkQYhyIALoraH   Transmission - Joris Voorn Remix   Joris Voorn
# 1     62piGIpUTsY8HA7tdjfLS8                           Electric      SANDHAUS
# 2     2QlUkqLbDDxDpiMcW7OJrZ  Dreaming - Casper Cole Remix Edit   Casper Cole
# 3     77FpsyFq4vGchrHovA8EyU                              Lissu         Wassu
# 4     3YDBOFmBEk19AS4t4gwpXq                            Arrival      Einmusik
# ...                      ...                                ...           ...
# 3361  5FvxRvrQ8qzKjBJ6ST9aiu   My Universe - David Guetta Remix  David Guetta
# 3362  2giNwwft9s8E5Or8N0olgc                 Skit: Expectation!           BTS
# 3363  6Lgbf4b6c9fwz24eFEWONX      My Universe - Supernova 7 Mix           BTS
# 3364  53XrsilgguJmmsEtDsj0yY               Skit: R U Happy Now?           BTS
# 3365  4Ut6UU8Yyihz1jCZWSCQpu             Skit: Circle Room Talk           BTS
#
#       popularity release_date  danceability    energy       key  loudness  \
# 0       0.070439   2022-10-28      0.555006  1.000686 -0.905065  0.307726
# 1      -0.628992   2022-11-25      0.768562  0.695290  1.588161 -0.026553
# 2      -2.350669   2022-10-07     -0.463960  1.117355 -0.073990  0.380151
# 3      -1.812645   2023-01-13      0.811273  1.264906 -0.351015  0.224190
# 4      -1.597435   2022-11-11      0.396365  0.904607 -0.905065  0.281755
# ...          ...          ...           ...       ...       ...       ...
# 3361   -0.521387   2021-10-13     -1.122932  1.378143 -1.182090  0.638391
# 3362   -0.951806   2015-04-29      0.091285 -1.301798  1.034111 -1.450286
# 3363   -0.951806   2021-09-27      0.274333  0.568327  0.203035  0.460876
# 3364   -0.736597   2013-09-11     -0.518874 -0.564042 -1.182090 -1.134749
# 3365   -0.682794   2013-06-12     -0.134474 -0.653259  1.034111 -1.034211
#
#           mode  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.795993     -0.180622          1.614257 -0.180952 -0.829171  0.183411
# 1    -1.256293     -0.944300          0.225070  0.403730 -1.572915  0.182930
# 2    -1.256293     -0.938245          1.490443 -0.380599 -0.990683  0.150130
# 3    -1.256293     -0.956649          1.505301 -0.788451 -1.297950  0.046234
# 4     0.795993     -0.958889          1.544921 -0.580247 -1.365313  0.183136
# ...        ...           ...               ...       ...       ...       ...
# 3361 -1.256293     -0.699644         -0.671958 -0.223733  1.034126  0.135567
# 3362 -1.256293      1.422320         -0.681244  2.350294  1.097155 -0.622273
# 3363 -1.256293     -0.956355         -0.680781  0.703202  0.218687 -0.468644
# 3364  0.795993      1.312968         -0.681244  0.995543  0.691405 -1.088518
# 3365  0.795993      1.472995         -0.681244  5.287965  1.510783  0.081850
#
#       duration_ms  time_signature  cluster
# 0        0.319202        0.236985       16
# 1       -0.390785        0.236985       11
# 2        0.950553        0.236985       11
# 3        0.463442        0.236985       11
# 4        3.561816        0.236985        8
# ...           ...             ...      ...
# 3361    -0.067027        0.236985        9
# 3362    -0.857400       -2.209154        0
# 3363     1.164917        0.236985        9
# 3364    -0.851577        0.236985       13
# 3365    -1.099957       -2.209154       18
#
# [3014 rows x 18 columns]

# %%
len(df.columns)
# Out:
# 13

# %%
add_df = pd.DataFrame(data=fetch,columns=['id','title','all_artists','popularity','release_date'])

merge = [add_df,df]
if len(df.columns) <18:
    df = pd.concat(merge,axis=1)
df
# Out:
#                           id                              title   all_artists  \
# 0     6ziqWx82jgkQYhyIALoraH   Transmission - Joris Voorn Remix   Joris Voorn
# 1     62piGIpUTsY8HA7tdjfLS8                           Electric      SANDHAUS
# 2     2QlUkqLbDDxDpiMcW7OJrZ  Dreaming - Casper Cole Remix Edit   Casper Cole
# 3     77FpsyFq4vGchrHovA8EyU                              Lissu         Wassu
# 4     3YDBOFmBEk19AS4t4gwpXq                            Arrival      Einmusik
# ...                      ...                                ...           ...
# 3361  5FvxRvrQ8qzKjBJ6ST9aiu   My Universe - David Guetta Remix  David Guetta
# 3362  2giNwwft9s8E5Or8N0olgc                 Skit: Expectation!           BTS
# 3363  6Lgbf4b6c9fwz24eFEWONX      My Universe - Supernova 7 Mix           BTS
# 3364  53XrsilgguJmmsEtDsj0yY               Skit: R U Happy Now?           BTS
# 3365  4Ut6UU8Yyihz1jCZWSCQpu             Skit: Circle Room Talk           BTS
#
#       popularity release_date  danceability    energy       key  loudness  \
# 0       0.070439   2022-10-28      0.555006  1.000686 -0.905065  0.307726
# 1      -0.628992   2022-11-25      0.768562  0.695290  1.588161 -0.026553
# 2      -2.350669   2022-10-07     -0.463960  1.117355 -0.073990  0.380151
# 3      -1.812645   2023-01-13      0.811273  1.264906 -0.351015  0.224190
# 4      -1.597435   2022-11-11      0.396365  0.904607 -0.905065  0.281755
# ...          ...          ...           ...       ...       ...       ...
# 3361   -0.521387   2021-10-13     -1.122932  1.378143 -1.182090  0.638391
# 3362   -0.951806   2015-04-29      0.091285 -1.301798  1.034111 -1.450286
# 3363   -0.951806   2021-09-27      0.274333  0.568327  0.203035  0.460876
# 3364   -0.736597   2013-09-11     -0.518874 -0.564042 -1.182090 -1.134749
# 3365   -0.682794   2013-06-12     -0.134474 -0.653259  1.034111 -1.034211
#
#           mode  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.795993     -0.180622          1.614257 -0.180952 -0.829171  0.183411
# 1    -1.256293     -0.944300          0.225070  0.403730 -1.572915  0.182930
# 2    -1.256293     -0.938245          1.490443 -0.380599 -0.990683  0.150130
# 3    -1.256293     -0.956649          1.505301 -0.788451 -1.297950  0.046234
# 4     0.795993     -0.958889          1.544921 -0.580247 -1.365313  0.183136
# ...        ...           ...               ...       ...       ...       ...
# 3361 -1.256293     -0.699644         -0.671958 -0.223733  1.034126  0.135567
# 3362 -1.256293      1.422320         -0.681244  2.350294  1.097155 -0.622273
# 3363 -1.256293     -0.956355         -0.680781  0.703202  0.218687 -0.468644
# 3364  0.795993      1.312968         -0.681244  0.995543  0.691405 -1.088518
# 3365  0.795993      1.472995         -0.681244  5.287965  1.510783  0.081850
#
#       duration_ms  time_signature  cluster
# 0        0.319202        0.236985        8
# 1       -0.390785        0.236985        7
# 2        0.950553        0.236985        0
# 3        0.463442        0.236985        0
# 4        3.561816        0.236985       10
# ...           ...             ...      ...
# 3361    -0.067027        0.236985        0
# 3362    -0.857400       -2.209154        2
# 3363     1.164917        0.236985        7
# 3364    -0.851577        0.236985        6
# 3365    -1.099957       -2.209154       12
#
# [3014 rows x 18 columns]

# %% [markdown]
# ## Playing with the parameters

# %%
kmeans.inertia_
# Out:
# 13758.041179480237

# %%
kmeans2 = KMeans(n_clusters=13,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=1,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 14945.769411737707

# %% [markdown]
# ## Choosing K

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ## Silhouette

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')

# %% [markdown]
# from yellowbrick.cluster import SilhouetteVisualizer
# model = KMeans(3, random_state=42)
# visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
# visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
# visualizer.show()        # Finalize and render the figure

# %% [markdown]
# ## getting user input

# %%
df100 = pd.read_csv('top100.csv')

# %%
def ask_input_title(df):
    list_of_songs = list(df['title'].unique())
    list_of_songs = [x.lower() for x in list_of_songs]
    while True:
        prompt = input(f'enter a song title of the Top100: ')
        if (prompt.lower() not in list_of_songs):
            print(f'Your choice is not in the Top100.')
            return [prompt.title(),0]
        else:
            options = df.loc[(df['title'] == prompt.title()),['artist']]
            options = options['artist'].tolist()
            options = [x.lower() for x in options]
            clarification = input(f' Your song might be in the list. Please state which artist you are referring to:')
            if (clarification.lower() not in options):
                print(f' Your combination of song title {prompt.title()} and artist {clarification.title()} is not in the Top 100')
                return [prompt.title(),0]
            else:
                print('Your Song is in the Top100 List :)')
                next_100 = random.choice(list_of_songs)
                while next_100.lower() == prompt.lower():
                    next_100 = random.choice(list_of_songs)
                return [next_100.title(),1]

# %%
song_choice = ask_input_title(df100)
song_choice

# %% [markdown]
# ## function for getting track_id from user input

# %%
def create_id(song_title):
    results = sp.search(q=song_title[0],limit=3)
    track_id=results["tracks"]["items"][0]["id"]
    return track_id
song_id = create_id(song_choice)

# %% [markdown]
# ## function for fetching audio features from a track_id and creating a dataframe

# %%
def audio_features_df(song):
    features = sp.audio_features(song)
    features_df = pd.DataFrame(data=features)
    features_df = features_df.select_dtypes(include=np.number)
    features_df = features_df[['danceability',
                           'energy',
                           'key',
                           'loudness',
                           'mode',
                           'acousticness',
                           'instrumentalness',
                           'liveness',
                           'valence',
                           'tempo',
                           'duration_ms',
                           'time_signature']]
    #returns a list with index 1 = audio features, index 2 = features dataframe
    return [features,features_df]

# %% [markdown]
# ## assigning list to a variable

# %%
afd = audio_features_df(song_id)

# %%
afd[1]

# %%
len(afd[1].columns)

# %%
afd[0]

# %% [markdown]
# ## scaling input and getting clusters

# %%
def scale_clust(list_of_features_and_df):
    features = list_of_features_and_df[0]
    features_df = list_of_features_and_df[1]
    input_scaled = scaler.transform(features_df)
    f_scaled_df = pd.DataFrame(input_scaled, columns = features_df.columns)
    clusters_f = kmeans.predict(f_scaled_df)
#dataframe creation, concat id with cluster    
    pd.Series(clusters_f).value_counts().sort_index()
    features_df["cluster"] = clusters_f
    add_df = pd.DataFrame(data=features)
    add_df = add_df['id']
    merge = [add_df,features_df]

#preventing multiple concats
    features_df = pd.concat(merge,axis=1)
    return features_df

# %% [markdown]
# #clusters
#     pd.Series(clusters_f).value_counts().sort_index()
#     features_df["cluster"] = clusters_f
#     add_df = pd.DataFrame(data=features)
#     add_df = add_df['id']
#     merge = [features_df,add_df]
#     features_df = pd.concat(merge,axis=1)
#     features_df = features_df[['id',
#                            'danceability',
#                            'energy',
#                            'key',
#                            'loudness',
#                            'mode',
#                            'acousticness',
#                            'instrumentalness',
#                            'liveness',
#                            'valence',
#                            'tempo',
#                            'duration_ms',
#                            'time_signature',
#                           'cluster']]
#     return df

# %%
final = scale_clust(afd)
final

# %%
def random_rec(df,choice_df):
    cluster_value = choice_df['cluster'][0]
    options = df.loc[(df['cluster'] == cluster_value),['id']]

#options.reset_index(inplace=True)
    range_id = options['id'].tolist()
    return random.choice(range_id)

# %%
def f(a):
    b = a * 3
    return b

# %%
f(2)

# %%
def g(c):
    d = c*2
    return d

# %%
f(g(2))

# %%
h = g(2)

# %%
f(h)

# %%
random_rec(df,final)

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
rec_song = random_rec(df,final)

# %%
rec_song

# %%
def song_recommender(df):
    song_choice = ask_input_title(df)
    if song_choice[1] == 0:
        track_id = create_id(song_choice)
        list = audio_features_df(track_id)
        features_df = scale_clust(list)
        rec_song = random_rec(df,features_df)
        display(play_song(rec_song))
   
    
    else:
        play_song(song_choice[0])

# %%
song_recommender(df100)

# %%
rec_song

# %%
IFrame(src="https://open.spotify.com/embed/track/"+rec_song,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
f1
f2
f3
f4
f5

y = f1(x)#
f2(y)
f2(f1(
f5(f4(f3(f2(f1(x)))))
